# %%
v = 0
c = 0
vowels=['a','e','i','o','u']
string = "consonents"
for i in string:
    if i in vowels:
        v += 1
    else:
        c += 1
print(v,c)
# Out:
# 3 7

# %%
A = [[1,8,9],
     [2,5,4]]
B = [[1,3],
     [4,5],
     [5,6]]
def matrix(A,B):
    a_col = len(A[0])
    b_row = len(B)
    if a_col == b_row:
        result = [[0 for _ in range(len(B[0]))] for _ in range(len(A))]
        for i in range(len(A)):
            for j in range(len(B[0])):
                for k in range(len(B)):
                    result[i][j] += A[i][k] * B[k][j]
        return result
    else:
        return "not possible matrix multiplication"

print(matrix(A,B))
# Out:
# [[78, 97], [42, 55]]

# %%
a = [1,2,3,4,17,6,18]
b = [18,9,7,8,17,0]
count = 0
for i in a:
    for j in b:
        if i == j:
            count += 1
        else:
            continue
print(count)
# Out:
# 2

# %%
a = [[1,2,3],
     [4,5,6],
     [7,8,9]]
def Transpose(a):
    cols = len(a[0])
    rows = len(a)
    transpose = []
    for j in range(cols):
        t_row = []
        for i in range(rows):
            t_row.append(a[i][j])
        transpose.append(t_row)
    return transpose
print(Transpose(a))
# Out:
# [[1, 4, 7], [2, 5, 8], [3, 6, 9]]

# %%
import random

n = 100
nums = [random.randint(100,150) for _ in range(n)]
mean = sum(nums) / n
#
nums_sorted = sorted(nums)
mid = n // 2
if n % 2 == 0:
    median = (nums_sorted[mid-1] + nums_sorted[mid]) / 2
else:
    median = nums_sorted[mid]
#
freq = {}
for num in nums:
    if num in freq:
        freq[num] += 1
    else:
        freq[num] = 1

mode = max(freq, key=freq.get)
print("Mean:", mean)
print("Median:", median)
print("Mode:", mode)
# Out:
# Mean: 124.51
# Median: 123.5
# Mode: 101
